# %%
#Our purpose is to determine the value of the used car

# %%
#Importing the libraries used
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('Datasets/Regression/vehicles.csv') #importing the dataframe 'test.csv' from the appropriate folder
df = df.drop(['Unnamed: 0'], axis = 1) #removing the column of default indexes: the change was not necessary, only
#for the sake of appearance
df
# Out:
#                 id                                                url  \
# 0       7240372487  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1       7240309422  https://auburn.craigslist.org/cto/d/auburn-201...
# 2       7240224296  https://auburn.craigslist.org/cto/d/auburn-200...
# 3       7240103965  https://auburn.craigslist.org/cto/d/lanett-tru...
# 4       7239983776  https://auburn.craigslist.org/cto/d/auburn-200...
# ...            ...                                                ...
# 458208  7240959076  https://wausau.craigslist.org/ctd/d/wisconsin-...
# 458209  7240954682  https://wausau.craigslist.org/ctd/d/wisconsin-...
# 458210  7240645700  https://wyoming.craigslist.org/cto/d/sheridan-...
# 458211  7240600465  https://wyoming.craigslist.org/cto/d/sheridan-...
# 458212  7240562359  https://wyoming.craigslist.org/ctd/d/gilberts-...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458213 entries, 0 to 458212
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            458213 non-null  int64
#  1   url           458213 non-null  object
#  2   region        458213 non-null  object
#  3   region_url    458213 non-null  object
#  4   price         458213 non-null  int64
#  5   year          457163 non-null  float64
#  6   manufacturer  439993 non-null  object
#  7   model         453367 non-null  object
#  8   condition     265273 non-null  object
#  9   cylinders     287073 non-null  object
#  10  fuel          454976 non-null  object
#  11  odometer      402910 non-null  float64
#  12  title_status  455636 non-null  object
#  13  transmission  455771 non-null  object
#  14  VIN           270664 non-null  object
#  15  drive         324025 non-null  object
#  16  size          136865 non-null  object
# ...

# %%
dfCopy = df.copy()

# %%
dfCopy = df.drop(['url', 'region_url', 'image_url', 'VIN'], axis = 1) #removing the columns of urls as well as VIN numbers -
#cluttering the dataset with no purpose for the future model or analysis
dfCopy
# Out:
#                 id   region  price    year manufacturer                 model  \
# 0       7240372487   auburn  35990  2010.0    chevrolet  corvette grand sport
# 1       7240309422   auburn   7500  2014.0      hyundai                sonata
# 2       7240224296   auburn   4900  2006.0          bmw               x3 3.0i
# 3       7240103965   auburn   2000  1974.0    chevrolet                  c-10
# 4       7239983776   auburn  19500  2005.0         ford           f350 lariat
# ...            ...      ...    ...     ...          ...                   ...
# 458208  7240959076   wausau  14995  2014.0     cadillac                   srx
# 458209  7240954682   wausau  17895  2018.0      hyundai                tucson
# 458210  7240645700  wyoming  17900  2014.0     cadillac         cts coupe awd
# 458211  7240600465  wyoming   1300  2008.0         jeep        grand cherokee
# 458212  7240562359  wyoming  22900  2008.0          NaN    International 4300
#
# ...
